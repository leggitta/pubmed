# %%
from Bio import Entrez
from bokeh.io import output_notebook
from bokeh.plotting import figure, show
import numpy as np
import os
import pandas as pd
import time
import sys

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ff54c3c4-5ee6-494a-be4c-ac8719e05fb3">Loading BokehJS ...</span>
#     </div>

# %%
Entrez.email = os.environ['EMAIL']  # replace this line with your email, or set an environment variable

# search with term
handle = Entrez.esearch(db="pubmed", term="ptsd combat veteran", retmax=int(1e6))
record = Entrez.read(handle)
handle.close()

# display the number of entries
print(record['Count'])
# Out:
# 2592

# %%
records = []      # list to store records
t0 = time.time()  # start time 
counter = 0       # records processed

# loop through the entries
for i in record["IdList"]:
    
    counter += 1
    
    # get the summary for this record
    h = Entrez.esummary(db="pubmed", id=i)
    rec, = Entrez.read(h)
    h.close()
    
    # update master list
    records.append(rec)
    
    # display progress
    dt = time.time() - t0
    line = '%d of %s. %.2f seconds' % (counter, record['Count'], dt)
    sys.stdout.write('\r%s' % line)
# Out:
# 2592 of 2592. 1135.42 seconds

# %%
# convert to data frame
record_table = pd.DataFrame(records)

# save to pickle file
record_table.to_pickle('ptsd_pubmed.pkl')

# %%
# compute the publication year (first 4 characters or PubDate field)
record_table['PubYear'] = record_table['PubDate'].apply(lambda s: int(s[:4]))

# %%
# count the number of records per year
by_year = record_table.groupby('PubYear')
year_counts = by_year['ArticleIds'].count()

# %%
x = year_counts.index
y = year_counts.values

# plot number of publications per year
fig = figure(width=900, height=400)
fig.line(x, y)
fig.circle(x, y)
show(fig)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0db1d1b1-de59-4063-9168-a056180d3ae3"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("0db1d1b1-de59-4063-9168-a056180d3ae3");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0db1d1b1-de59-4063-9168-a056180d3ae3");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0db1d1b1-de59-4063-9168-a056180d3ae3' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"78eecca6-8328-4ec8-8e73-0627cd3677c6":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1966,1973,1974,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017],"y":[1,1,1,1,8,23,15,20,24,14,33,25,33,37,32,34,42,62,52,66,77,58,59,66,47,54,59,56,56,80,89,98,116,126,131,138,167,181,166,160,84]}},"id":"55f40d3e-7d01-4ce8-847b-a32d49c6ba06","type":"ColumnDataSource"},{"attributes":{},"id":"3f7d51aa-66be-4e29-a0fa-1bc7f32dbe58","type":"ToolEvents"},{"attributes":{"callback":null},"id":"f4d63713-dff7-4a1a-9610-a90048c592b8","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"87e37f5b-055a-4732-8235-5cee219116bb","type":"PanTool"},{"id":"6a18fd58-6bf2-4b15-93ef-de23152088a4","type":"WheelZoomTool"},{"id":"51b722af-05f5-4e19-811f-7b7f51ee6baa","type":"BoxZoomTool"},{"id":"65758b92-5c06-46d8-ae04-a9aa7d8007a8","type":"SaveTool"},{"id":"791c3121-868d-4f9b-a952-b8e548e0ec66","type":"ResetTool"},{"id":"9551e792-1747-4709-bb7f-d6ec6628a1a9","type":"HelpTool"}]},"id":"72b2ef25-b4ce-47fe-8370-63f089104146","type":"Toolbar"},{"attributes":{"callback":null},"id":"4aa4be34-b742-4ae6-8c5f-bcd4ec49000e","type":"DataRange1d"},{"attributes":{},"id":"98de3b70-8052-45f5-9f40-babf76c6e0a1","type":"LinearScale"},{"attributes":{},"id":"464465d8-fb8b-438f-8953-65ac80faf3fc","type":"LinearScale"},{"attributes":{"formatter":{"id":"ecfeb95a-6e63-47d5-9075-9040219c3c3d","type":"BasicTickFormatter"},"plot":{"id":"6b0f0efa-bb58-4d30-9f6d-c5ecc5074150","subtype":"Figure","type":"Plot"},"ticker":{"id":"ce8aa8aa-658c-4382-a663-33a244de047a","type":"BasicTicker"}},"id":"49c33955-9096-4c33-9e26-c95ad8eaa091","type":"LinearAxis"},{"attributes":{},"id":"ecfeb95a-6e63-47d5-9075-9040219c3c3d","type":"BasicTickFormatter"},{"attributes":{},"id":"ce8aa8aa-658c-4382-a663-33a244de047a","type":"BasicTicker"},{"attributes":{"plot":{"id":"6b0f0efa-bb58-4d30-9f6d-c5ecc5074150","subtype":"Figure","type":"Plot"},"ticker":{"id":"ce8aa8aa-658c-4382-a663-33a244de047a","type":"BasicTicker"}},"id":"969d898c-5f29-4498-a30b-393f55bd2437","type":"Grid"},{"attributes":{"formatter":{"id":"c2361be4-eae5-4541-baa7-1a80988db43f","type":"BasicTickFormatter"},"plot":{"id":"6b0f0efa-bb58-4d30-9f6d-c5ecc5074150","subtype":"Figure","type":"Plot"},"ticker":{"id":"eb47597f-6a95-4041-ae6c-194fb8271815","type":"BasicTicker"}},"id":"28a931b6-fdda-413d-912d-2df880c5ea9e","type":"LinearAxis"},{"attributes":{},"id":"eb47597f-6a95-4041-ae6c-194fb8271815","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"6b0f0efa-bb58-4d30-9f6d-c5ecc5074150","subtype":"Figure","type":"Plot"},"ticker":{"id":"eb47597f-6a95-4041-ae6c-194fb8271815","type":"BasicTicker"}},"id":"c805c35a-4a3c-4b6d-afe4-73af143a0ee5","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"2c8b604c-0d63-4a42-8442-655f6c07c786","type":"BoxAnnotation"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1966,1973,1974,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017],"y":[1,1,1,1,8,23,15,20,24,14,33,25,33,37,32,34,42,62,52,66,77,58,59,66,47,54,59,56,56,80,89,98,116,126,131,138,167,181,166,160,84]}},"id":"19c8d300-181e-4af6-b625-5aaf762a48fc","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field" ...
