# %%
import math

from bokeh.io import output_notebook
from bokeh.plotting import figure, show
from bokeh.models import GraphRenderer, StaticLayoutProvider, Oval
from bokeh.palettes import Spectral8

output_notebook()

N = 8
node_indices = list(range(N))

plot = figure(title="Graph Layout Demonstration", x_range=(-1.1,1.1), y_range=(-1.1,1.1),
              tools="", toolbar_location=None)

graph = GraphRenderer()

graph.node_renderer.glyph = Oval(height=0.1, width=0.2, fill_color="fill_color")
graph.node_renderer.data_source.data = dict(
    index=node_indices,
    fill_color=Spectral8)

graph.edge_renderer.data_source.data = dict(
    start=[0]*N,
    end=node_indices)

### start of layout code
circ = [i*2*math.pi/8 for i in node_indices]
x = [math.cos(i) for i in circ]
y = [math.sin(i) for i in circ]

graph_layout = dict(zip(node_indices, zip(x, y)))
graph.layout_provider = StaticLayoutProvider(graph_layout=graph_layout)

plot.renderers.append(graph)

show(plot)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="30c25188-7ca2-4638-bfaf-bf5efa31defd">Loading BokehJS ...</span>
#     </div>
# E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: fill_color [renderer: GlyphRenderer(id='ce26679e-04b4-41ad-9792-fecd02f66511', ...)]
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="57d5848b-379d-4883-b5bc-a0d6326a9b4c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("57d5848b-379d-4883-b5bc-a0d6326a9b4c");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("57d5848b-379d-4883-b5bc-a0d6326a9b4c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '57d5848b-379d-4883-b5bc-a0d6326a9b4c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"18f4fd8e-829a-4506-a603-ec49cf6ec4fd":{"roots":{"references":[{"attributes":{},"id":"656a6575-76a8-4ce8-bbbd-0f9477a87b9a","type":"BasicTickFormatter"},{"attributes":{},"id":"0d7dc281-07f7-4e13-a34e-07a1a93d0eb9","type":"BasicTickFormatter"},{"attributes":{"callback":null,"end":1.1,"start":-1.1},"id":"94e53b4e-a29e-4ff2-88db-41f2ef70be29","type":"Range1d"},{"attributes":{"callback":null,"column_names":["index"],"data":{"fill_color":["#3288bd","#66c2a5","#abdda4","#e6f598","#fee08b","#fdae61","#f46d43","#d53e4f"],"index":[0,1,2,3,4,5,6,7]}},"id":"0f4eb081-f8d0-48c2-a563-2f1e85eccf9d","type":"ColumnDataSource"},{"attributes":{"source":{"id":"0f4eb081-f8d0-48c2-a563-2f1e85eccf9d","type":"ColumnDataSource"}},"id":"ad8eb449-bc18-429d-b6df-24194f4ae3e9","type":"CDSView"},{"attributes":{"callback":null,"column_names":["start","end"],"data":{"end":[0,1,2,3,4,5,6,7],"start":[0,0,0,0,0,0,0,0]}},"id":"950978b3-5b9f-4346-b4dc-95240aed2723","type":"ColumnDataSource"},{"attributes":{},"id":"34c0bba9-80af-4981-8a40-772e59c388ce","type":"NodesOnly"},{"attributes":{},"id":"6ce14e70-b9cc-4c36-a4d0-20bc61fe4e96","type":"LinearScale"},{"attributes":{"graph_layout":{"0":[1.0,0.0],"1":[0.7071067811865476,0.7071067811865475],"2":[6.123233995736766e-17,1.0],"3":[-0.7071067811865475,0.7071067811865476],"4":[-1.0,1.2246467991473532e-16],"5":[-0.7071067811865477,-0.7071067811865475],"6":[-1.8369701987210297e-16,-1.0],"7":[0.7071067811865475,-0.7071067811865477]}},"id":"f151a81e-54a5-4550-a694-b6985f0f9372","type":"StaticLayoutProvider"},{"attributes":{"callback":null,"end":1.1,"start":-1.1},"id":"d4b82204-26f6-4240-b9bf-6dc89065d7c6","type":"Range1d"},{"attributes":{},"id":"aa6a892c-4732-4bec-935a-d27ae0f75905","type":"LinearScale"},{"attributes":{"plot":{"id":"c371fa17-278a-4858-a3bc-cd79d6071057","subtype":"Figure","type":"Plot"},"ticker":{"id":"73894d66-fba5-41d0-96bf-ccb4fd3dc9a8","type":"BasicTicker"}},"id":"7a64182a-7710-482d-a04e-70c1cacd42e2","type":"Grid"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto"},"id":"f25f00e5-8adb-4505-93de-648899af1d37","type":"Toolbar"},{"attributes":{"formatter":{"id":"656a6575-76a8-4ce8-bbbd-0f9477a87b9a","type":"BasicTickFormatter"},"plot":{"id":"c371fa17-278a-4858-a3bc-cd79d6071057","subtype":"Figure","type":"Plot"},"ticker":{"id":"73894d66-fba5-41d0-96bf-ccb4fd3dc9a8","type":"BasicTicker"}},"id":"eef97e86-553f-40a8-868f-0ccd9a54072a","type":"LinearAxis"},{"attributes":{"data_source":{"id":"950978b3-5b9f-4346-b4dc-95240aed2723","type":"ColumnDataSource"},"glyph":{"id":"b53f0950-a698-4bc4-86b5-abaa1262dbd5","type":"MultiLine"},"hover_glyph":null,"muted_glyph":null,"view":{"id":"9e90884a-3d35-4a5f-bcd7-7eac831bca20","type":"CDSView"}},"id":"10a4d147-fa29-41e9-bc20-33ca6a40f418","type":"GlyphRenderer"},{"attributes":{},"id":"73894d66-fba5-41d0-96bf-ccb4fd3dc9a8","type":"BasicTicker"},{"attributes":{"plot":null,"text":"Graph Layout Demonstration"},"id":"eb2624a3-9f47-4dc7-b8e5-d0bcd0fd2da6","type":"Title"},{"attributes":{"formatter":{"id":"0d7dc281-07f7-4e13-a34e-07a1a93d0eb9","type":"BasicTickFormatter"},"plot":{"id":"c371fa17-278a-4858-a3bc-cd79d6071057","subtype":"Figure","type":"Plot"},"ticker":{"id":"e152ee97-164f-49b0-856b-1b889669da48","type":"BasicTicker"}},"id":"5060f218-ff0f-4c3a-995a-6f65d0fcc11d","type":"LinearAxis"},{"attributes":{},"id":"e152ee97-164f-49b0-856b-1b889669da48","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"c371fa17-278a-4858-a3bc-cd79d6071057","subtype":"Figure","type":"Plot"},"ticker":{"id":"e152ee97-164f-49b0-856b-1b889669da48","type":"BasicTicker"}},"id":"d9c4c814-5fe3-4518-8a4a-c402f6b05d40","type":"Grid"},{"attributes":{"data_source":{"id":"0f4eb081-f8d0-48c2-a563-2f1e85eccf9d","type":"ColumnDataSource"},"glyph":{"id":"3626b855-13e7-4717-96e8-07235a992b74","type":"Oval"},"hover_glyph":null,"muted_glyph":null,"view":{"id":"ad8eb449-bc18-429d-b6df-24194f4ae3e9","type":"CDSView"}},"id ...
